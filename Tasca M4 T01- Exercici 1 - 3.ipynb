# %% [markdown]
# o Descarrega el dataset adjunt preu lloguer per trimestre i barri.csv extret de la web OpenDataBCN i resumeix-lo estadísticament i gràficament.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Preu lloguer per trimestre i barri analisis.xlsx")
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
df.describe()
# Out:
#           Any   Trimestre  Codi_Districte  Codi_Barri
# count   584.0  584.000000      584.000000  584.000000
# mean   2021.0    2.500000        6.246575   37.000000
# std       0.0    1.118992        2.790726   21.089371
# min    2021.0    1.000000        1.000000    1.000000
# 25%    2021.0    1.750000        4.000000   19.000000
# 50%    2021.0    2.500000        7.000000   37.000000
# 75%    2021.0    3.250000        8.000000   55.000000
# max    2021.0    4.000000       10.000000   73.000000

# %%
df.shape
# Out:
# (584, 8)

# %%
df.Lloguer_mitja.unique()
# Out:
# array(['Lloguer mitjà mensual (Euros/mes)',
#        'Lloguer mitjà per superfície (Euros/m2 mes)'], dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Preu lloguer per trimestre i barri analisis.xlsx")
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
Preu = df['Preu'].mean
Preu
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      759.2
# 1      929.6
# 2      808.9
# 3      879.4
# 4      918.0
#        ...
# 579     15.2
# 580     10.8
# 581     13.8
# 582     11.7
# 583     11.3
# Name: Preu, Length: 584, dtype: object>

# %%
Variable_preu = df.groupby(['Preu']).mean()
Variable_preu
# Out:
#           Any  Trimestre  Codi_Districte  Codi_Barri
# Preu
# --     2021.0   2.454545        7.000000   43.636364
# 10.0   2021.0   3.000000        8.000000   49.000000
# 10.1   2021.0   2.000000        8.500000   52.500000
# 10.2   2021.0   3.166667        6.666667   39.666667
# 10.4   2021.0   1.000000        7.000000   39.000000
# ...       ...        ...             ...         ...
# 982.9  2021.0   3.000000        4.000000   20.000000
# 990.1  2021.0   1.000000        5.000000   27.000000
# 990.3  2021.0   1.000000        4.000000   19.000000
# 998.3  2021.0   4.000000        5.000000   27.000000
# 998.8  2021.0   2.000000        4.000000   19.000000
#
# [331 rows x 4 columns]

# %%
Variable_preu1 = Variable_preu.drop(columns = ['Codi_Districte', 'Codi_Barri', 'Any'])
Variable_preu1
# Out:
#        Trimestre
# Preu
# --      2.454545
# 10.0    3.000000
# 10.1    2.000000
# 10.2    3.166667
# 10.4    1.000000
# ...          ...
# 982.9   3.000000
# 990.1   1.000000
# 990.3   1.000000
# 998.3   4.000000
# 998.8   2.000000
#
# [331 rows x 1 columns]

# %% [markdown]
# o Una variable numèrica (Preu)

# %% [markdown]
# El gràfic illustra el promedi de lloguer per trimestre - (No he pogut aconseguir un millor gràfic)

# %%
Variable_preu1.plot(kind ="bar")
# Out:
# <AxesSubplot:xlabel='Preu'>

# %% [markdown]
# o Una variable numèrica i una categòrica (Districte i Preu)

# %%
df_exercici3 = dataframe_euros.groupby(["Nom_Districte"])[["Lloguer_mitja","Preu"]].max()
df_exercici3
# Out:
#                                          Lloguer_mitja   Preu
# Nom_Districte
# Ciutat Vella         Lloguer mitjà mensual (Euros/mes)  968.4
# Eixample             Lloguer mitjà mensual (Euros/mes)  976.9
# Gràcia               Lloguer mitjà mensual (Euros/mes)  961.0
# Horta-Guinardó       Lloguer mitjà mensual (Euros/mes)  884.2
# Les Corts            Lloguer mitjà mensual (Euros/mes)  998.8
# Nou Barris           Lloguer mitjà mensual (Euros/mes)  803.7
# Sant Andreu          Lloguer mitjà mensual (Euros/mes)  827.2
# Sant Martí           Lloguer mitjà mensual (Euros/mes)  978.4
# Sants-Montjuïc       Lloguer mitjà mensual (Euros/mes)  872.5
# Sarrià-Sant Gervasi  Lloguer mitjà mensual (Euros/mes)  998.3

# %%
df_exercici4 = dataframe_euros.groupby(["Nom_Districte"])[["Preu"]].max()
df_exercici4
# Out:
#                       Preu
# Nom_Districte
# Ciutat Vella         968.4
# Eixample             976.9
# Gràcia               961.0
# Horta-Guinardó       884.2
# Les Corts            998.8
# Nou Barris           803.7
# Sant Andreu          827.2
# Sant Martí           978.4
# Sants-Montjuïc       872.5
# Sarrià-Sant Gervasi  998.3

# %%
df_exercici4
# Out:
#                       Preu
# Nom_Districte
# Ciutat Vella         968.4
# Eixample             976.9
# Gràcia               961.0
# Horta-Guinardó       884.2
# Les Corts            998.8
# Nou Barris           803.7
# Sant Andreu          827.2
# Sant Martí           978.4
# Sants-Montjuïc       872.5
# Sarrià-Sant Gervasi  998.3

# %%
df_exercici4.dtypes
# Out:
# Preu    object
# dtype: object

# %%
df=df_exercici4.astype(float)
df
# Out:
#                       Preu
# Nom_Districte
# Ciutat Vella         968.4
# Eixample             976.9
# Gràcia               961.0
# Horta-Guinardó       884.2
# Les Corts            998.8
# Nou Barris           803.7
# Sant Andreu          827.2
# Sant Martí           978.4
# Sants-Montjuïc       872.5
# Sarrià-Sant Gervasi  998.3

# %% [markdown]
# El gràfic illustra el preus máxims de lloguer per Districtre

# %%
df.plot(kind ="bar")
# Out:
# <AxesSubplot:xlabel='Nom_Districte'>

# %% [markdown]
# o	Dues variables numèriques (Any o Trimestre i Preu)

# %%
df = pd.read_excel("Preu lloguer per trimestre i barri analisis.xlsx")
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
pivota = pd.pivot_table(df, index = ['Trimestre'], values = ['Preu'], aggfunc = ['max'])
pivota.fillna('0', inplace = True)
print(pivota)
# Out:
#              max
#             Preu
# Trimestre
# 1          990.3
# 2          998.8
# 3          982.9
# 4          998.3

# %%
df_grafico = pivota.astype(float)
df_grafico
# Out:
#              max
#             Preu
# Trimestre
# 1          990.3
# 2          998.8
# 3          982.9
# 4          998.3

# %% [markdown]
# El gràfic illustra una comparació els preus máxims segon el trimestre

# %%
df_grafico.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Trimestre'>

# %% [markdown]
# o	Tres variables (Barri o Districte, Trimestre i Preu)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Preu lloguer per trimestre i barri analisis.xlsx")
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from gapminder import gapminder # data set
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [37], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 import seaborn as sns
# ----> 3 from gapminder import gapminder
#
# ModuleNotFoundError: No module named 'gapminder'

# %%
# data
#data = gapminder.loc[gapminder.year == 2007]

# use the scatterplot function to build the bubble map
sns.scatterplot(data=df, x="Nom_Districte", y="Trimestre", size="Preu", legend=False, sizes=(20, 2000))

# show the graph
plt.show()

# %%
# data
#data = gapminder.loc[gapminder.year == 2007]

# use the scatterplot function to build the bubble map
sns.scatterplot(data=df, x="Trimestre", y="Nom_Districte", size="Preu", legend=False, sizes=(2, 200))

# show the graph
plt.show()

# %%
df = pd.read_excel("Preu lloguer per trimestre i barri analisis.xlsx")
df
# Out:
#       Any  Trimestre  Codi_Districte Nom_Districte  Codi_Barri  \
# 0    2021          1               1  Ciutat Vella           1
# 1    2021          1               1  Ciutat Vella           2
# 2    2021          1               1  Ciutat Vella           3
# 3    2021          1               1  Ciutat Vella           4
# 4    2021          1               2      Eixample           5
# ..    ...        ...             ...           ...         ...
# 579  2021          4              10    Sant Martí          69
# 580  2021          4              10    Sant Martí          70
# 581  2021          4              10    Sant Martí          71
# 582  2021          4              10    Sant Martí          72
# 583  2021          4              10    Sant Martí          73
#
#                                         Nom_Barri  \
# 0                                        el Raval
# 1                                  el Barri Gòtic
# 2                                  la Barceloneta
# ...

# %%
pd.pivot_table(df, index = ['Trimestre'], columns = ['Nom_Districte'], values = ['Preu'],aggfunc = 'sum')
# Out:
#                                                Preu  \
# Nom_Districte                          Ciutat Vella
# Trimestre
# 1              759.2929.6808.9879.412.812.315.513.3
# 2              774.2934.1814.8862.112.912.715.913.6
# 3              770.5968.4826.0889.112.912.916.313.4
# 4              772.8953.0877.9922.813.112.416.414.0
#
#                                                                   \
# Nom_Districte                                           Eixample
# Trimestre
# 1              918.0887.11176.71040.2964.0898.712.913.513.013...
# 2              907.1887.41196.31070.1953.3928.812.713.513.113...
# 3              970.2912.41168.41072.9968.6934.313.213.613.013...
# 4              976.9924.41220.81114.9965.9955.713.313.713.514...
#
#                                                               \
# Nom_Districte                                         Gràcia
# Trimestre
# 1              959.0745.4859.1910.6865.313.612.512.814.213.6
# ...

# %%
pd.pivot_table(df, index = ['Trimestre'], columns = ['Nom_Districte'], values = ['Preu'],aggfunc = 'max')
# Out:
#                       Preu                                           \
# Nom_Districte Ciutat Vella Eixample Gràcia Horta-Guinardó Les Corts
# Trimestre
# 1                    929.6    964.0  959.0          827.0     990.3
# 2                    934.1    953.3  924.5          884.2     998.8
# 3                    968.4    970.2  961.0          878.1     982.9
# 4                    953.0    976.9  926.5            9.5     920.6
#
#                                                                 \
# Nom_Districte Nou Barris Sant Andreu Sant Martí Sants-Montjuïc
# Trimestre
# 1                    9.9       824.2      978.4          829.1
# 2                    8.7       827.2      948.3          815.4
# 3                    9.4       805.3      971.3          858.7
# 4                    9.4         9.2      977.8          872.5
#
#
# Nom_Districte Sarrià-Sant Gervasi
# Trimestre
# 1                           990.1
# 2                            15.9
# ...

# %%
grafico_variables = pd.pivot_table(df, index = ['Trimestre'], columns = ['Nom_Districte'], values = ['Preu'],aggfunc = 'max')
grafico_variables
# Out:
#                       Preu                                           \
# Nom_Districte Ciutat Vella Eixample Gràcia Horta-Guinardó Les Corts
# Trimestre
# 1                    929.6    964.0  959.0          827.0     990.3
# 2                    934.1    953.3  924.5          884.2     998.8
# 3                    968.4    970.2  961.0          878.1     982.9
# 4                    953.0    976.9  926.5            9.5     920.6
#
#                                                                 \
# Nom_Districte Nou Barris Sant Andreu Sant Martí Sants-Montjuïc
# Trimestre
# 1                    9.9       824.2      978.4          829.1
# 2                    8.7       827.2      948.3          815.4
# 3                    9.4       805.3      971.3          858.7
# 4                    9.4         9.2      977.8          872.5
#
#
# Nom_Districte Sarrià-Sant Gervasi
# Trimestre
# 1                           990.1
# 2                            15.9
# ...

# %%
df1_grafico = grafico_variables.astype(float)
df1_grafico
# Out:
#                       Preu                                           \
# Nom_Districte Ciutat Vella Eixample Gràcia Horta-Guinardó Les Corts
# Trimestre
# 1                    929.6    964.0  959.0          827.0     990.3
# 2                    934.1    953.3  924.5          884.2     998.8
# 3                    968.4    970.2  961.0          878.1     982.9
# 4                    953.0    976.9  926.5            9.5     920.6
#
#                                                                 \
# Nom_Districte Nou Barris Sant Andreu Sant Martí Sants-Montjuïc
# Trimestre
# 1                    9.9       824.2      978.4          829.1
# 2                    8.7       827.2      948.3          815.4
# 3                    9.4       805.3      971.3          858.7
# 4                    9.4         9.2      977.8          872.5
#
#
# Nom_Districte Sarrià-Sant Gervasi
# Trimestre
# 1                           990.1
# 2                            15.9
# ...

# %% [markdown]
# Aquest gràfic illustra una comparació dels preus máxims segon el Districtre i segon el trimestre

# %%
df1_grafico.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Trimestre'>

# %%
dataframe = df1_grafico.reset_index()
dataframe
# Out:
#               Trimestre         Preu                                           \
# Nom_Districte           Ciutat Vella Eixample Gràcia Horta-Guinardó Les Corts
# 0                     1        929.6    964.0  959.0          827.0     990.3
# 1                     2        934.1    953.3  924.5          884.2     998.8
# 2                     3        968.4    970.2  961.0          878.1     982.9
# 3                     4        953.0    976.9  926.5            9.5     920.6
#
#                                                                 \
# Nom_Districte Nou Barris Sant Andreu Sant Martí Sants-Montjuïc
# 0                    9.9       824.2      978.4          829.1
# 1                    8.7       827.2      948.3          815.4
# 2                    9.4       805.3      971.3          858.7
# 3                    9.4         9.2      977.8          872.5
#
#
# Nom_Districte Sarrià-Sant Gervasi
# 0                           990.1
# 1                            15.9
# ...

# %% [markdown]
# o Una variable categòrica (Districte)

# %% [markdown]
# El gràfic illustra el quantitat de Districtes que apareixen en la recopilació de dades

# %%
Variable_Districte = df.groupby("Nom_Districte").count()
Variable_Districte
# Out:
#                      Any  Trimestre  Codi_Districte  Codi_Barri  Nom_Barri  \
# Nom_Districte
# Ciutat Vella          32         32              32          32         32
# Eixample              48         48              48          48         48
# Gràcia                40         40              40          40         40
# Horta-Guinardó        88         88              88          88         88
# Les Corts             24         24              24          24         24
# Nou Barris           104        104             104         104        104
# Sant Andreu           56         56              56          56         56
# Sant Martí            80         80              80          80         80
# Sants-Montjuïc        64         64              64          64         64
# Sarrià-Sant Gervasi   48         48              48          48         48
#
#                      Lloguer_mitja  Preu
# Nom_Districte
# Ciutat Vella                    32    32
# ...

# %%
Variable_Districte.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Nom_Districte'>
